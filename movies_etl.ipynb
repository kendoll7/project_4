# %%
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', 400)

# %%
movies_df = pd.read_csv('csvs/train.csv')
movies_df.head()
# Out:
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                                                                  belongs_to_collection  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine Collection', 'poster_path': '/iEhb00TGPucF0b4joM1ieyY026U.jpg', 'backdrop_path': '/noeTVcgpBiD48fDjFVic1Vz7ope.jpg'}]
# 1  [{'id': 107674, 'name': 'The Princess Diaries Collection', 'poster_path': '/wt5AMbxPTS4Kfjx7Fgm149qPfZl.jpg', 'backdrop_path': '/zSEtYD77pKRJlUPx34BJgUG9v1c.jpg'}]
# 2                                                                                                                                                                  NaN
# 3                                                                                                                                                                  NaN
# ...

# %%
movies_df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
movies_df_clean = movies_df.drop(['homepage', 'imdb_id', 'original_language', 
                                  'overview', 'poster_path', 'production_countries', 'status',
                                 'crew', 'tagline', 'belongs_to_collection'], axis=1)
movies_df_clean.head()
# Out:
#    id    budget  \
# 0   1  14000000
# 1   2  40000000
# 2   3   3300000
# 3   4   1200000
# 4   5         0
#
#                                                                                                                            genres  \
# 0                                                                                                  [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]
# 2                                                                                                   [{'id': 18, 'name': 'Drama'}]
# 3                                                                   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}]
# 4                                                                  [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]
#
#                              original_title  popularity  \
# ...

# %%
movies_df_2 = pd.read_csv('csvs/test.csv')
movies_df_2.head()
# Out:
#      id  \
# 0  3001
# 1  3002
# 2  3003
# 3  3004
# 4  3005
#
#                                                                                                                                    belongs_to_collection  \
# 0  [{'id': 34055, 'name': 'Pokémon Collection', 'poster_path': '/j5te0YNZAMXDBnsqTUDKIBEt8iu.jpg', 'backdrop_path': '/iGoYKA0TFfgSoZpG2u5viTJMGfK.jpg'}]
# 1                                                                                                                                                    NaN
# 2                                                                                                                                                    NaN
# 3                                                                                                                                                    NaN
# 4                                                                                                                                                    NaN
#
# ...

# %%
movies_df_2.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew'],
#       dtype='object')

# %%
movies_df_2_clean = movies_df_2.drop(['homepage', 'imdb_id', 'original_language', 
                                  'overview', 'poster_path', 'production_countries', 'status',
                                 'crew', 'tagline', 'belongs_to_collection'], axis=1)
movies_df_2_clean.head()
# Out:
#      id   budget  \
# 0  3001        0
# 1  3002    88000
# 2  3003        0
# 3  3004  6800000
# 4  3005  2000000
#
#                                                                                                                                genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}]
# 1                                                              [{'id': 27, 'name': 'Horror'}, {'id': 878, 'name': 'Science Fiction'}]
# 2                                                                    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]
# 3                                        [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'name': 'War'}, {'id': 9648, 'name': 'Mystery'}]
# 4                                                                  [{'id': 36, 'name': 'History'}, {'id': 99, 'name': 'Documentary'}]
#
#                 original_title  popularity  \
# ...

# %%
complete_movies_df_clean = pd.concat([movies_df_clean, movies_df_2_clean])
complete_movies_df_clean.head(10)
# Out:
#    id    budget  \
# 0   1  14000000
# 1   2  40000000
# 2   3   3300000
# 3   4   1200000
# 4   5         0
# 5   6   8000000
# 6   7  14000000
# 7   8         0
# 8   9         0
# 9  10   6000000
#
#                                                                                                                                                            genres  \
# 0                                                                                                                                  [{'id': 35, 'name': 'Comedy'}]
# 1                                  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]
# 2                                                                                                                                   [{'id': 18, 'name': 'Drama'}]
# ...

# %%
complete_movies_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7398 entries, 0 to 4397
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    7398 non-null   int64
#  1   budget                7398 non-null   int64
#  2   genres                7375 non-null   object
#  3   original_title        7398 non-null   object
#  4   popularity            7398 non-null   float64
#  5   production_companies  6984 non-null   object
#  6   release_date          7397 non-null   object
#  7   runtime               7392 non-null   float64
#  8   spoken_languages      7336 non-null   object
#  9   title                 7395 non-null   object
#  10  Keywords              6729 non-null   object
#  11  cast                  7372 non-null   object
#  12  revenue               3000 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 809.2+ KB

# %%
complete_movies_rename = complete_movies_df_clean.rename(columns={"cast": "actors"})
complete_movies_rename
# Out:
#         id    budget  \
# 0        1  14000000
# 1        2  40000000
# 2        3   3300000
# 3        4   1200000
# 4        5         0
# ...    ...       ...
# 4393  7394  42000000
# 4394  7395  19000000
# 4395  7396  16000000
# 4396  7397   2000000
# 4397  7398     64000
#
#                                                                                                                               genres  \
# 0                                                                                                     [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]
# 2                                                                                                      [{'id': 18, 'name': 'Drama'}]
# 3                                                                      [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}]
# ...

# %%
nan_counts = complete_movies_df_clean.isna().sum()
nan_counts
# Out:
# id                         0
# budget                     0
# genres                    23
# original_title             0
# popularity                 0
# production_companies     414
# release_date               1
# runtime                    6
# spoken_languages          62
# title                      3
# Keywords                 669
# cast                      26
# revenue                 4398
# dtype: int64

# %%
complete_movies_df_clean_all = complete_movies_rename.dropna()
complete_movies_df_clean_all
# Out:
#         id    budget  \
# 0        1  14000000
# 1        2  40000000
# 2        3   3300000
# 8        9         0
# 9       10   6000000
# ...    ...       ...
# 2995  2996         0
# 2996  2997         0
# 2997  2998  65000000
# 2998  2999  42000000
# 2999  3000  35000000
#
#                                                                                                                                                               genres  \
# 0                                                                                                                                     [{'id': 35, 'name': 'Comedy'}]
# 1                                     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]
# 2                                                                                                                                      [{'id': 18, 'name': 'Drama'}]
# ...

# %%
complete_movies_df_clean_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2616 entries, 0 to 2999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    2616 non-null   int64
#  1   budget                2616 non-null   int64
#  2   genres                2616 non-null   object
#  3   original_title        2616 non-null   object
#  4   popularity            2616 non-null   float64
#  5   production_companies  2616 non-null   object
#  6   release_date          2616 non-null   object
#  7   runtime               2616 non-null   float64
#  8   spoken_languages      2616 non-null   object
#  9   title                 2616 non-null   object
#  10  Keywords              2616 non-null   object
#  11  actors                2616 non-null   object
#  12  revenue               2616 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 286.1+ KB

# %%
complete_movies_df_clean.to_csv('clean_csvs/complete_movie_list.csv', index=False)
